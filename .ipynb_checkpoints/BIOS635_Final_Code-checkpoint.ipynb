# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import seaborn as sns

from xgboost import XGBClassifier
import optuna

from sklearn.model_selection import (
    train_test_split, cross_val_score, GridSearchCV
)
from sklearn.metrics import (
    recall_score, f1_score, roc_auc_score,
    accuracy_score, precision_score,
    roc_curve, precision_recall_curve, auc,
    ConfusionMatrixDisplay, confusion_matrix
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\ashle\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Load data for Tram
data = pd.read_csv("/Users/tbhuynh/Desktop/UNC_PHD/BIOS635/Final Project/train.csv")
submission = pd.read_csv("/Users/tbhuynh/Desktop/UNC_PHD/BIOS635/Final Project/test.csv")

# %%
# Load data for Ashley
data = pd.read_csv("C:/Users/ashle/OneDrive/Documents/Courses/UNC Courses/BIOS 635 - ML/Final/train.csv")
submission = pd.read_csv("C:/Users/ashle/OneDrive/Documents/Courses/UNC Courses/BIOS 635 - ML/Final/test.csv")

# %%
# Examine data
print(data.shape)
print(submission.shape)

# Calculate percentage of NaNs per column
nan_data = data.isna().mean() * 100

for col, i in nan_data.items():
    print(f"{col}: {i:.2f}% missing")
    
nan_submission = submission.isna().mean() * 100

for col, i in nan_submission.items():
    print(f"{col}: {i:.2f}% missing")
# Out:
# (140700, 20)
# (93800, 19)
# id: 0.00% missing
# Name: 0.00% missing
# Gender: 0.00% missing
# Age: 0.00% missing
# City: 0.00% missing
# Working Professional or Student: 0.00% missing
# Profession: 26.03% missing
# Academic Pressure: 80.17% missing
# Work Pressure: 19.84% missing
# CGPA: 80.17% missing
# Study Satisfaction: 80.17% missing
# Job Satisfaction: 19.84% missing
# Sleep Duration: 0.00% missing
# Dietary Habits: 0.00% missing
# Degree: 0.00% missing
# Have you ever had suicidal thoughts ?: 0.00% missing
# Work/Study Hours: 0.00% missing
# Financial Stress: 0.00% missing
# Family History of Mental Illness: 0.00% missing
# Depression: 0.00% missing
# id: 0.00% missing
# Name: 0.00% missing
# Gender: 0.00% missing
# Age: 0.00% missing
# City: 0.00% missing
# Working Professional or Student: 0.00% missing
# Profession: 26.26% missing
# Academic Pressure: 79.99% missing
# Work Pressure: 20.02% missing
# CGPA: 79.99% missing
# Study Satisfaction: 79.99% missing
# Job Satisfaction: 20.01% missing
# Sleep Duration: 0.00% missing
# Dietary Habits: 0.01% missing
# Degree: 0.00% missing
# Have you ever had suicidal thoughts ?: 0.00% missing
# Work/Study Hours: 0.00% missing
# Financial Stress: 0.00% missing
# Family History of Mental Illness: 0.00% missing

# %%
# Drop id and Name
submission_ids = submission['id'].copy()
data.drop(['id', 'Name'], axis=1, inplace=True)
submission.drop(['id', 'Name'], axis=1, inplace=True)

# Handle sleep duration feature
def process_sleep_duration(sleep_value):
    try:
        if isinstance(sleep_value, str):
            # Handle "Less than 5 hours" and "More than 8 hours"
            if 'Less than 5 hours' in sleep_value:
                return 4.5
            if 'More than 8 hours' in sleep_value:
                return 9.0

            # Handle range cases like "6-7 hours" or "40-45 hours"
            if '-' in sleep_value and 'hours' in sleep_value:
                parts = sleep_value.split(' ')[0].split('-')
                a = float(parts[0])
                b = float(parts[1])
                avg = (a + b) / 2
                if a > 24 and b > 24:
                    return avg / 7  # weekly sleep range
                else:
                    return avg  # daily sleep range

            # Handle single number cases
            elif sleep_value.isdigit():
                value = float(sleep_value)
                if value > 24:
                    return value / 7  # weekly sleep
                else:
                    return value  # daily sleep

            # Handle messy or typos cases like 5-6hours if had
            elif 'hours' in sleep_value:
                num = sleep_value.split(' ')[0]
                if '-' in num:
                    parts = num.split('-')
                    a = float(parts[0])
                    b = float(parts[1])
                    avg = (a + b) / 2
                    if a > 24 and b > 24:
                        return avg / 7
                    else:
                        return avg
                else:
                    value = float(num)
                    if value > 24:
                        return value / 7
                    else:
                        return value
            else:
                return np.nan  # weird garbage entry
        else:
            return np.nan
    except:
        return np.nan

# %%
# Apply sleep duration processing
data['Sleep Duration Processed'] = data['Sleep Duration'].apply(process_sleep_duration)
submission['Sleep Duration Processed'] = submission['Sleep Duration'].apply(process_sleep_duration)

# Remove rows where Sleep Duration could not be processed
data = data[~data['Sleep Duration Processed'].isnull()]
submission = submission[~submission['Sleep Duration Processed'].isnull()]

# Replace old Sleep Duration
data.drop(columns=['Sleep Duration'], inplace=True)
submission.drop(columns=['Sleep Duration'], inplace=True)
data.rename(columns={'Sleep Duration Processed': 'Sleep Duration'}, inplace=True)
submission.rename(columns={'Sleep Duration Processed': 'Sleep Duration'}, inplace=True)

# %%
# Drop heavily missing columns
drop_cols = ['Academic Pressure', 'CGPA', 'Study Satisfaction']
data.drop(columns=drop_cols, inplace=True)
submission.drop(columns=drop_cols, inplace=True)

# %%
# Add missing indicators for 20% missing values of features
for col in ['Work Pressure', 'Job Satisfaction']:
    new_col = f'is_{col.replace(" ", "_")}_missing'
    data[new_col] = data[col].isnull().astype(int)
    submission[new_col] = submission[col].isnull().astype(int)
    
# Fill moderate missing values with median
for col in ['Work Pressure', 'Job Satisfaction']:
    median = data[col].median()
    data[col].fillna(median, inplace=True)
    submission[col].fillna(median, inplace=True)

# %%
# Fill missing categorical values
data['Profession'].fillna('Unknown', inplace=True) # Profession has higher than 20% of missing 
submission['Profession'].fillna('Unknown', inplace=True)

# %%
# Small missing in submission
mode = submission['Dietary Habits'].mode()[0]
submission['Dietary Habits'].fillna(mode, inplace=True)

# Mapping
dietary_mapping = {
    # Healthy
    'Healthy': 'Healthy',
    'Yes': 'Healthy',
    'More Healthy': 'Healthy',
    '5 Healthy': 'Healthy',
    
    # Unhealthy
    'Unhealthy': 'Unhealthy',
    'No': 'Unhealthy',
    'No Healthy': 'Unhealthy',
    'Less Healthy': 'Unhealthy',
    'Less than Healthy': 'Unhealthy',
    '5 Unhealthy': 'Unhealthy',
    
    # Neutral
    'Moderate': 'Neutral'
}

# Apply mapping
data['Dietary Habits'] = data['Dietary Habits'].map(dietary_mapping).fillna('Other')
submission['Dietary Habits'] = submission['Dietary Habits'].map(dietary_mapping).fillna('Other')

from sklearn.preprocessing import LabelEncoder
# Label Encode binary categorical column
le = LabelEncoder()
data['Dietary Habits'] = le.fit_transform(data['Dietary Habits'])
submission['Dietary Habits'] = le.transform(submission['Dietary Habits'])

# %%
# Group rare observations into 'Other' so that we have less dummies -> better for one hot encoder
city_counts = data['City'].value_counts()
rare_cities = city_counts[city_counts < 100].index
data['City'] = data['City'].replace(rare_cities, 'Other')
submission['City'] = submission['City'].replace(submission['City'].value_counts()[submission['City'].value_counts() < 100].index, 'Other')

profession_counts = data['Profession'].value_counts()
rare_professions = profession_counts[profession_counts < 100].index
data['Profession'] = data['Profession'].replace(rare_professions, 'Other')
submission['Profession'] = submission['Profession'].replace(submission['Profession'].value_counts()[submission['Profession'].value_counts() < 100].index, 'Other')

degree_counts = data['Degree'].value_counts()
rare_degree = degree_counts[degree_counts < 100].index
data['Degree'] = data['Degree'].replace(rare_degree, 'Other')
submission['Degree'] = submission['Degree'].replace(submission['Degree'].value_counts()[submission['Degree'].value_counts() < 100].index, 'Other')

# One-hot encode multicategorical columns
data = pd.get_dummies(data, columns=['City', 'Profession', 'Degree', 'Gender', 'Working Professional or Student', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness'])
submission = pd.get_dummies(submission, columns=['City', 'Profession', 'Degree', 'Gender', 'Working Professional or Student', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness'])

# %%
missing_cols_in_data = data.isnull().sum()
missing_cols_in_data = missing_cols_in_data[missing_cols_in_data > 0]
print(missing_cols_in_data)
# Out:
# Financial Stress    4
# dtype: int64

# %%
data.fillna(0, inplace=True)

# %%
# Check
print(f"Number of rows with NaN in Train now: {data.isnull().any(axis=1).sum()}")    
print(f"Number of rows with NaN in Test now: {submission.isnull().any(axis=1).sum()}") 
print(data.shape)
print(submission.shape)
# Out:
# Number of rows with NaN in Train now: 0
# Number of rows with NaN in Test now: 0
# (140686, 114)
# (93792, 113)

# %% [markdown]
# # Models

# %% [markdown]
# Model 1: XGBoost

# %%
# Run XGBoost

def tune_xgb_classifier(data_df):
    # 1. Prepare features and target
    X = data_df.drop('Depression', axis=1)
    y = data_df['Depression']

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42, stratify=y
    )

    # 2. Define Optuna objective
    def objective(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
            'reg_lambda': trial.suggest_float('reg_lambda', 0.1, 10.0, log=True),
            'reg_alpha': trial.suggest_float('reg_alpha', 0.1, 10.0, log=True),
            'n_jobs': -1 # faster running
        }

        model = XGBClassifier(**params, use_label_encoder=False, eval_metric='logloss')
        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        return accuracy_score(y_test, preds)

    # 3. Run Optuna study
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=25)

    # 4. Train best model
    best_model = XGBClassifier(**study.best_params, use_label_encoder=False, eval_metric='logloss')
    best_model.fit(X_train, y_train)
    start_time = time.time()
    preds = best_model.predict(X_test)
    end_time = time.time()
    
    run_time = end_time - start_time

    return best_model, preds, run_time

# %%
xgb_model, xgb_preds, xgb_time = tune_xgb_classifier(data)
# Out:
# [I 2025-04-27 22:27:21,662] A new study created in memory with name: no-name-47e9fc5d-473f-44f0-8586-efa9328587a0
# [I 2025-04-27 22:27:24,618] Trial 0 finished with value: 0.9298677913092925 and parameters: {'n_estimators': 300, 'learning_rate': 0.09118060754181935, 'max_depth': 6, 'subsample': 0.9378729424428263, 'colsample_bytree': 0.6482186530206573, 'min_child_weight': 2, 'reg_lambda': 2.297482719142399, 'reg_alpha': 1.2606140039385216}. Best is trial 0 with value: 0.9298677913092925.
# [I 2025-04-27 22:27:29,765] Trial 1 finished with value: 0.9304838174667109 and parameters: {'n_estimators': 760, 'learning_rate': 0.06813091596520279, 'max_depth': 3, 'subsample': 0.6859413255226041, 'colsample_bytree': 0.627744826675843, 'min_child_weight': 2, 'reg_lambda': 1.0549142998977996, 'reg_alpha': 1.253032410692747}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:27:39,162] Trial 2 finished with value: 0.9297730180543051 and parameters: {'n_estimators': 850, 'learning_rate': 0.028072388217409747, 'max_depth': 8, 'subsample': 0.5636861217825226, 'colsample_bytree': 0.8688883757393149, 'min_child_weight': 8, 'reg_lambda': 0.20376102943808494, 'reg_alpha': 2.164706979524053}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:27:43,813] Trial 3 finished with value: 0.9299862578780268 and parameters: {'n_estimators': 370, 'learning_rate': 0.02165864807055106, 'max_depth': 8, 'subsample': 0.7372367956807568, 'colsample_bytree': 0.8281500414484682, 'min_child_weight': 10, 'reg_lambda': 1.6216099738885332, 'reg_alpha': 0.13309349385269406}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:27:53,701] Trial 4 finished with value: 0.9279723262095436 and parameters: {'n_estimators': 860, 'learning_rate': 0.057160977652924244, 'max_depth': 9, 'subsample': 0.7383485798210201, 'colsample_bytree': 0.5999602623366693, 'min_child_weight': 6, 'reg_lambda': 0.29194164115862753, 'reg_alpha': 0.33226538887723994}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:00,213] Trial 5 finished with value: 0.9297730180543051 and parameters: {'n_estimators': 440, 'learning_rate': 0.03659922563174127, 'max_depth': 8, 'subsample': 0.5275076563738395, 'colsample_bytree': 0.9103461336422682, 'min_child_weight': 6, 'reg_lambda': 0.1272970830424838, 'reg_alpha': 1.2480131824323724}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:12,187] Trial 6 finished with value: 0.9263374875610103 and parameters: {'n_estimators': 780, 'learning_rate': 0.18379279864010423, 'max_depth': 7, 'subsample': 0.5594211712745046, 'colsample_bytree': 0.9614064181607862, 'min_child_weight': 5, 'reg_lambda': 3.4802696607706185, 'reg_alpha': 4.671381531845351}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:15,748] Trial 7 finished with value: 0.9297256314268113 and parameters: {'n_estimators': 130, 'learning_rate': 0.04086559893807067, 'max_depth': 10, 'subsample': 0.5695830509537712, 'colsample_bytree': 0.6523386187477125, 'min_child_weight': 2, 'reg_lambda': 0.20075974965899368, 'reg_alpha': 0.26498902521799}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:25,322] Trial 8 finished with value: 0.9297019381130645 and parameters: {'n_estimators': 510, 'learning_rate': 0.03773470688964539, 'max_depth': 9, 'subsample': 0.8767735512578059, 'colsample_bytree': 0.6244699136774656, 'min_child_weight': 3, 'reg_lambda': 0.6447810896493295, 'reg_alpha': 0.9730508764676083}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:34,668] Trial 9 finished with value: 0.92996256456428 and parameters: {'n_estimators': 720, 'learning_rate': 0.09760783626580843, 'max_depth': 5, 'subsample': 0.6564082116363322, 'colsample_bytree': 0.8500670217703424, 'min_child_weight': 5, 'reg_lambda': 0.4534166611571913, 'reg_alpha': 2.8933163906100985}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:45,939] Trial 10 finished with value: 0.9289674453869118 and parameters: {'n_estimators': 980, 'learning_rate': 0.010447010807562383, 'max_depth': 3, 'subsample': 0.8284621069385256, 'colsample_bytree': 0.5326825259080896, 'min_child_weight': 1, 'reg_lambda': 9.944423252246809, 'reg_alpha': 9.837169159072058}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:54,033] Trial 11 finished with value: 0.9298204046817988 and parameters: {'n_estimators': 660, 'learning_rate': 0.01681120716652934, 'max_depth': 3, 'subsample': 0.739038058310702, 'colsample_bytree': 0.7558206385070736, 'min_child_weight': 10, 'reg_lambda': 1.4466684230046662, 'reg_alpha': 0.10400061188786022}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:28:59,903] Trial 12 finished with value: 0.9295360849168365 and parameters: {'n_estimators': 410, 'learning_rate': 0.018331478547414674, 'max_depth': 4, 'subsample': 0.664248169001273, 'colsample_bytree': 0.7570247164630912, 'min_child_weight': 10, 'reg_lambda': 1.1435234961060268, 'reg_alpha': 0.445943027300273}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:29:03,419] Trial 13 finished with value: 0.9274273799933659 and parameters: {'n_estimators': 240, 'learning_rate': 0.2980233709829898, 'max_depth': 6, 'subsample': 0.6584147640545169, 'colsample_bytree': 0.7922825877252757, 'min_child_weight': 4, 'reg_lambda': 3.9792734820887574, 'reg_alpha': 0.1618020350260209}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:29:10,423] Trial 14 finished with value: 0.9304601241529641 and parameters: {'n_estimators': 590, 'learning_rate': 0.0756015534906775, 'max_depth': 5, 'subsample': 0.81925514475044, 'colsample_bytree': 0.5118075215871956, 'min_child_weight': 8, 'reg_lambda': 0.8027824389832912, 'reg_alpha': 0.6577099799166698}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:29:16,986] Trial 15 finished with value: 0.9300099511917737 and parameters: {'n_estimators': 600, 'learning_rate': 0.08986310235630939, 'max_depth': 4, 'subsample': 0.823781849588593, 'colsample_bytree': 0.5071631846993833, 'min_child_weight': 8, 'reg_lambda': 0.6871025503983712, 'reg_alpha': 0.6822996705556243}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:29:24,539] Trial 16 finished with value: 0.9304601241529641 and parameters: {'n_estimators': 560, 'learning_rate': 0.1451294445869245, 'max_depth': 4, 'subsample': 0.9788928970102548, 'colsample_bytree': 0.5740958101972067, 'min_child_weight': 8, 'reg_lambda': 0.6788116721901808, 'reg_alpha': 0.5696891297236542}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:29:37,351] Trial 17 finished with value: 0.9297256314268113 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06369727717850701, 'max_depth': 5, 'subsample': 0.8112317308191493, 'colsample_bytree': 0.693217301722132, 'min_child_weight': 8, 'reg_lambda': 6.331390682003844, 'reg_alpha': 2.1951643908540666}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:29:46,634] Trial 18 finished with value: 0.9282329526607591 and parameters: {'n_estimators': 730, 'learning_rate': 0.17104129182944142, 'max_depth': 5, 'subsample': 0.6877156262975089, 'colsample_bytree': 0.6992266946482636, 'min_child_weight': 7, 'reg_lambda': 2.213280943561048, 'reg_alpha': 0.8401535575523266}. Best is trial 1 with value: 0.9304838174667109.
# [I 2025-04-27 22:29:55,687] Trial 19 finished with value: 0.9307207506041795 and parameters: {'n_estimators': 870, 'learning_rate': 0.07374401742438196, 'max_depth': 3, 'subsample': 0.8935276736211994, 'colsample_bytree': 0.5653881870676627, 'min_child_weight': 4, 'reg_lambda': 0.3804777343059391, 'reg_alpha': 1.8486199724134533}. Best is trial 19 with value: 0.9307207506041795.
# [I 2025-04-27 22:30:05,410] Trial 20 finished with value: 0.9304838174667109 and parameters: {'n_estimators': 850, 'learning_rate': 0.12329039293441844, 'max_depth': 3, 'subsample': 0.9067521228603442, 'colsample_bytree': 0.5638823471259999, 'min_child_weight': 3, 'reg_lambda': 0.4182688851863851, 'reg_alpha': 4.834303257744094}. Best is trial 19 with value: 0.9307207506041795.
# [I 2025-04-27 22:30:15,917] Trial 21 finished with value: 0.9306970572904326 and parameters: {'n_estimators': 890, 'learning_rate': 0.12761947874705584, 'max_depth': 3, 'subsample': 0.8911342463323364, 'colsample_bytree': 0.5883847850889836, 'min_child_weight': 3, 'reg_lambda': 0.35609769955804554, 'reg_alpha': 5.651238291271753}. Best is trial 19 with value: 0.9307207506041795.
# [I 2025-04-27 22:30:26,898] Trial 22 finished with value: 0.9303179642704829 and parameters: {'n_estimators': 920, 'learning_rate': 0.26480137266407966, 'max_depth': 3, 'subsample': 0.8835077878018095, 'colsample_bytree': 0.689380236274699, 'min_child_weight': 4, 'reg_lambda': 0.3572947568199915, 'reg_alpha': 9.61129691478401}. Best is trial 19 with value: 0.9307207506041795.
# [I 2025-04-27 22:30:36,561] Trial 23 finished with value: 0.9306259773491921 and parameters: {'n_estimators': 790, 'learning_rate': 0.05116962286326719, 'max_depth': 4, 'subsample': 0.9558730424650566, 'colsample_bytree': 0.5845270371911524, 'min_child_weight': 1, 'reg_lambda': 0.11811305225836613, 'reg_alpha': 5.018281651941991}. Best is trial 19 with value: 0.9307207506041795.
# [I 2025-04-27 22:30:47,415] Trial 24 finished with value: 0.9303890442117234 and parameters: {'n_estimators': 920, 'learning_rate': 0.05033816633132235, 'max_depth': 4, 'subsample': 0.9989115911060209, 'colsample_bytree': 0.556003627132787, 'min_child_weight': 1, 'reg_lambda': 0.10924294149889328, 'reg_alpha': 5.53396473595665}. Best is trial 19 with value: 0.9307207506041795.

# %% [markdown]
# Model 2: k-NN

# %%
# Split into features and target
X = data.drop('Depression', axis=1)
y = data['Depression']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# Cross validation to find best k
k_range = range(1, 16)
cv_scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train, y_train, cv=5, scoring='accuracy', verbose=2)
    cv_scores.append(scores.mean())

optimal_k = k_range[np.argmax(cv_scores)]
print(f"Optimal k: {optimal_k}, Accuracy: {max(cv_scores):.4f}")

# Train K-Nearest Neighbors classifier
knn_model = KNeighborsClassifier(n_neighbors=optimal_k)
knn_model.fit(X_train, y_train)

# Predict
start_time = time.time()
knn_preds = knn_model.predict(X_val)
end_time = time.time()

knn_time = end_time - start_time
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   4.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.1s remaining:    0.0s
# [CV] END .................................................... total time=   3.8s
# [CV] END .................................................... total time=   3.7s
# [CV] END .................................................... total time=   3.9s
# [CV] END .................................................... total time=   4.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   19.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   3.9s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.9s remaining:    0.0s
# [CV] END .................................................... total time=   4.0s
# [CV] END .................................................... total time=   4.0s
# [CV] END .................................................... total time=   4.7s
# [CV] END .................................................... total time=   5.8s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   22.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   5.8s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.8s remaining:    0.0s
# [CV] END .................................................... total time=   6.3s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   6.4s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   32.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.3s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.3s remaining:    0.0s
# [CV] END .................................................... total time=   6.3s
# [CV] END .................................................... total time=   6.5s
# [CV] END .................................................... total time=   6.6s
# [CV] END .................................................... total time=   6.6s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   32.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.4s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.4s remaining:    0.0s
# [CV] END .................................................... total time=   6.4s
# [CV] END .................................................... total time=   6.5s
# [CV] END .................................................... total time=   6.6s
# [CV] END .................................................... total time=   6.5s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   32.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.6s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.7s remaining:    0.0s
# [CV] END .................................................... total time=   6.4s
# [CV] END .................................................... total time=   6.6s
# [CV] END .................................................... total time=   6.5s
# [CV] END .................................................... total time=   6.4s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   33.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   7.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.1s remaining:    0.0s
# [CV] END .................................................... total time=   7.4s
# [CV] END .................................................... total time=   6.6s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   7.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   35.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   7.3s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.4s remaining:    0.0s
# [CV] END .................................................... total time=   7.0s
# [CV] END .................................................... total time=   7.5s
# [CV] END .................................................... total time=   7.2s
# [CV] END .................................................... total time=   7.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   36.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.7s remaining:    0.0s
# [CV] END .................................................... total time=   6.8s
# [CV] END .................................................... total time=   6.7s
# [CV] END .................................................... total time=   7.1s
# [CV] END .................................................... total time=   6.6s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   34.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.6s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.6s remaining:    0.0s
# [CV] END .................................................... total time=   7.0s
# [CV] END .................................................... total time=   7.4s
# [CV] END .................................................... total time=   7.2s
# [CV] END .................................................... total time=   6.9s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   35.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.9s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.0s remaining:    0.0s
# [CV] END .................................................... total time=   7.3s
# [CV] END .................................................... total time=   7.2s
# [CV] END .................................................... total time=   7.2s
# [CV] END .................................................... total time=   6.9s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   36.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.8s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.8s remaining:    0.0s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   6.8s
# [CV] END .................................................... total time=   6.8s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   34.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   6.8s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.8s remaining:    0.0s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   6.8s
# [CV] END .................................................... total time=   7.7s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   35.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   7.2s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.2s remaining:    0.0s
# [CV] END .................................................... total time=   6.8s
# [CV] END .................................................... total time=   6.7s
# [CV] END .................................................... total time=   6.7s
# [CV] END .................................................... total time=   6.7s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   34.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   7.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.0s remaining:    0.0s
# [CV] END .................................................... total time=   6.7s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   6.9s
# [CV] END .................................................... total time=   7.7s
# Optimal k: 14, Accuracy: 0.9218
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   35.7s finished

# %% [markdown]
# Model 3: L1 Logistic Regression

# %%
# Grid search to find optimal tuning parameter, lambda
grid = {'C': [.0001, .001, .01, .1, 1, 10, 100]}
lasso = LogisticRegression(penalty='l1', solver='liblinear', random_state=42)
grid_search = GridSearchCV(lasso, grid, cv=5, scoring='accuracy', verbose=2)

# Get best model
grid_search.fit(X_train, y_train)
lasso_model = grid_search.best_estimator_

# Make predictions
start_time = time.time()
lasso_preds = lasso_model.predict(X_val)
end_time = time.time()

lasso_time = end_time - start_time
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV] END ...........................................C=0.0001; total time=   0.3s
# [CV] END ...........................................C=0.0001; total time=   0.4s
# [CV] END ...........................................C=0.0001; total time=   0.4s
# [CV] END ...........................................C=0.0001; total time=   0.3s
# [CV] END ...........................................C=0.0001; total time=   0.4s
# [CV] END ............................................C=0.001; total time=   0.6s
# [CV] END ............................................C=0.001; total time=   0.6s
# [CV] END ............................................C=0.001; total time=   0.5s
# [CV] END ............................................C=0.001; total time=   0.6s
# [CV] END ............................................C=0.001; total time=   0.6s
# [CV] END .............................................C=0.01; total time=   0.8s
# [CV] END .............................................C=0.01; total time=   0.9s
# [CV] END .............................................C=0.01; total time=   0.9s
# [CV] END .............................................C=0.01; total time=   1.0s
# [CV] END .............................................C=0.01; total time=   0.9s
# [CV] END ..............................................C=0.1; total time=   1.0s
# [CV] END ..............................................C=0.1; total time=   1.1s
# [CV] END ..............................................C=0.1; total time=   1.3s
# [CV] END ..............................................C=0.1; total time=   1.2s
# [CV] END ..............................................C=0.1; total time=   0.9s
# [CV] END ................................................C=1; total time=   1.4s
# [CV] END ................................................C=1; total time=   1.6s
# [CV] END ................................................C=1; total time=   1.7s
# [CV] END ................................................C=1; total time=   1.2s
# [CV] END ................................................C=1; total time=   1.4s
# [CV] END ...............................................C=10; total time=   1.1s
# [CV] END ...............................................C=10; total time=   1.2s
# [CV] END ...............................................C=10; total time=   1.2s
# [CV] END ...............................................C=10; total time=   1.2s
# [CV] END ...............................................C=10; total time=   1.3s
# [CV] END ..............................................C=100; total time=   1.2s
# [CV] END ..............................................C=100; total time=   1.2s
# [CV] END ..............................................C=100; total time=   1.1s
# [CV] END ..............................................C=100; total time=   1.2s
# [CV] END ..............................................C=100; total time=   1.2s

# %% [markdown]
# Model 4: Random Forest

# %%
# Grid search to find best model
rf = RandomForestClassifier(random_state=42)
grid = {'n_estimators': [10, 25, 50],     # num of trees
        'max_features': ['sqrt', 'log2']}   # num of predictors at each split

tune_rf = GridSearchCV(rf, grid, cv=5, scoring='accuracy', verbose=2)
tune_rf.fit(X_train, y_train)

# Get best model
rf_model = tune_rf.best_estimator_
rf_best_param = tune_rf.best_params_
print("Best parameters:", rf_best_param)

# Make predictions
start_time = time.time()
rf_preds = rf_model.predict(X_val)
end_time = time.time()

rf_time = end_time - start_time
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .................max_features=sqrt, n_estimators=10; total time=   1.8s
# [CV] END .................max_features=sqrt, n_estimators=10; total time=   1.5s
# [CV] END .................max_features=sqrt, n_estimators=10; total time=   1.7s
# [CV] END .................max_features=sqrt, n_estimators=10; total time=   2.0s
# [CV] END .................max_features=sqrt, n_estimators=10; total time=   1.9s
# [CV] END .................max_features=sqrt, n_estimators=25; total time=   4.2s
# [CV] END .................max_features=sqrt, n_estimators=25; total time=   4.3s
# [CV] END .................max_features=sqrt, n_estimators=25; total time=   4.0s
# [CV] END .................max_features=sqrt, n_estimators=25; total time=   4.4s
# [CV] END .................max_features=sqrt, n_estimators=25; total time=   4.3s
# [CV] END .................max_features=sqrt, n_estimators=50; total time=   8.6s
# [CV] END .................max_features=sqrt, n_estimators=50; total time=   8.7s
# [CV] END .................max_features=sqrt, n_estimators=50; total time=   8.6s
# [CV] END .................max_features=sqrt, n_estimators=50; total time=   8.3s
# [CV] END .................max_features=sqrt, n_estimators=50; total time=   8.9s
# [CV] END .................max_features=log2, n_estimators=10; total time=   1.5s
# [CV] END .................max_features=log2, n_estimators=10; total time=   1.6s
# [CV] END .................max_features=log2, n_estimators=10; total time=   1.6s
# [CV] END .................max_features=log2, n_estimators=10; total time=   1.3s
# [CV] END .................max_features=log2, n_estimators=10; total time=   1.5s
# [CV] END .................max_features=log2, n_estimators=25; total time=   3.6s
# [CV] END .................max_features=log2, n_estimators=25; total time=   3.7s
# [CV] END .................max_features=log2, n_estimators=25; total time=   3.7s
# [CV] END .................max_features=log2, n_estimators=25; total time=   4.0s
# [CV] END .................max_features=log2, n_estimators=25; total time=   3.9s
# [CV] END .................max_features=log2, n_estimators=50; total time=   7.4s
# [CV] END .................max_features=log2, n_estimators=50; total time=   7.7s
# [CV] END .................max_features=log2, n_estimators=50; total time=   7.2s
# [CV] END .................max_features=log2, n_estimators=50; total time=   7.3s
# [CV] END .................max_features=log2, n_estimators=50; total time=   7.1s
# Best parameters: {'max_features': 'sqrt', 'n_estimators': 50}

# %% [markdown]
# # Evaluation

# %%
# Evaluation results

def evaluate_model(name, y_true, y_pred, y_prob=None, time=None):
    print(f"\n📊  {name} Evaluation Metrics")
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall   : {rec:.4f}")
    print(f"F1 Score : {f1:.4f}")

    if y_prob is not None:
        roc_auc = roc_auc_score(y_true, y_prob)
        print(f"ROC AUC  : {roc_auc:.4f}")
    else:
        roc_auc = None

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    ConfusionMatrixDisplay(cm).plot()
    plt.title(f"{name} Confusion Matrix")
    plt.show()

    # ROC Curve
    if y_prob is not None:
        fpr, tpr, _ = roc_curve(y_true, y_prob)
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--')
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"{name} ROC Curve")
        plt.legend()
        plt.grid()
        plt.show()

        # Precision-Recall Curve
        precs, recalls, _ = precision_recall_curve(y_true, y_prob)
        pr_auc = auc(recalls, precs)
        plt.plot(recalls, precs, label=f"AUC = {pr_auc:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title(f"{name} Precision-Recall Curve")
        plt.legend()
        plt.grid()
        plt.show()

    return {
        "Model": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1 Score": f1,
        "ROC AUC": roc_auc,
        "Run Time (s)": time
    }

# %%
def train_eval_metrics(name, model, X_train, y_train):
    y_train_pred = model.predict(X_train)
    
    acc = accuracy_score(y_train, y_train_pred)
    prec = precision_score(y_train, y_train_pred)
    rec = recall_score(y_train, y_train_pred)
    f1 = f1_score(y_train, y_train_pred)
    
    return {
        "Model": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1 Score": f1,
    }

# %%
# Run evaluations for all 4 models
xgb_prob = xgb_model.predict_proba(X_val)[:, 1]
xgb_results = evaluate_model("XGBoost", y_val, xgb_preds, xgb_prob, xgb_time)
xgb_train_res = train_eval_metrics("XGBoost", xgb_model, X_train, y_train)

knn_prob = knn_model.predict_proba(X_val)[:, 1]
knn_results = evaluate_model(f"KNN (k={optimal_k})", y_val, knn_preds, knn_prob, knn_time)
knn_train_res = train_eval_metrics(f"KNN (k={optimal_k})", knn_model, X_train, y_train)

lasso_prob = lasso_model.predict_proba(X_val)[:, 1]
lasso_results = evaluate_model("Lasso", y_val, lasso_preds, lasso_prob, lasso_time)
lasso_train_res = train_eval_metrics("Lasso", lasso_model, X_train, y_train)

rf_prob = rf_model.predict_proba(X_val)[:, 1]
rf_results = evaluate_model("Random Forest", y_val, rf_preds, rf_prob, rf_time)
rf_train_res = train_eval_metrics("Random Forest", rf_model, X_train, y_train)

# Comparison table
comparison_df = pd.DataFrame([xgb_results, knn_results, lasso_results, rf_results])
print("\n📋 Model Comparison Table on Test Set")
print(comparison_df)

train_comparision_df = pd.DataFrame([xgb_train_res, knn_train_res, lasso_train_res, rf_train_res])
print("\n Model Comparision Table on Training Set")
print(train_comparision_df)
# Out:
# 📊  XGBoost Evaluation Metrics
# Accuracy : 0.9307
# Precision: 0.8133
# Recall   : 0.8031
# F1 Score : 0.8082
# ROC AUC  : 0.9697
# 📊  KNN (k=14) Evaluation Metrics
# Accuracy : 0.9221
# Precision: 0.7983
# Recall   : 0.7643
# F1 Score : 0.7809
# ROC AUC  : 0.9541
# 📊  Lasso Evaluation Metrics
# Accuracy : 0.9294
# Precision: 0.8149
# Recall   : 0.7914
# F1 Score : 0.8030
# ROC AUC  : 0.9683
# 📊  Random Forest Evaluation Metrics
# Accuracy : 0.9259
# Precision: 0.8169
# Recall   : 0.7634
# F1 Score : 0.7892
# ROC AUC  : 0.9635
# 📋 Model Comparison Table on Test Set
#            Model  Accuracy  Precision    Recall  F1 Score   ROC AUC  \
# 0        XGBoost  0.930721   0.813309  0.803129  0.808187  0.969692
# 1     KNN (k=14)  0.922073   0.798311  0.764276  0.780923  0.954100
# 2          Lasso  0.929418   0.814874  0.791395  0.802963  0.968280
# 3  Random Forest  0.925911   0.816939  0.763364  0.789243  0.963459
#
#    Run Time (s)
# 0      0.202422
# 1     20.301821
# 2      0.036855
# 3      0.590144
#
#  Model Comparision Table on Training Set
#            Model  Accuracy  Precision    Recall  F1 Score
# 0        XGBoost  0.935449   0.826875  0.815556  0.821176
# 1     KNN (k=14)  0.931286   0.825362  0.788791  0.806663
# 2          Lasso  0.931377   0.821323  0.795441  0.808175
# 3  Random Forest  0.999878   0.999721  0.999609  0.999665

# %%
# Model comparison table as dataframe
df = pd.DataFrame(comparison_df)

# Make plot grouping metrics together 
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']
df_melted = df.melt(id_vars='Model', value_vars=metrics, var_name='Metric', value_name='Score')
plt.figure(figsize=(10, 6))
ax1 = sns.barplot(data=df_melted, x='Metric', y='Score', hue='Model')
plt.title('Model Performance Metrics Comparison')
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Feature importance for XGBoost
importances = xgb_model.feature_importances_
feature_names = X_train.columns
sorted_idx = np.argsort(importances)[::-1][:20]  # Top 20 features

plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_idx)), importances[sorted_idx][::-1], align='center')
plt.yticks(range(len(sorted_idx)), feature_names[sorted_idx][::-1])
plt.xlabel('Feature Importance Score')
plt.title('Top 20 Most Important Features (XGBoost)')
plt.tight_layout()
plt.show()

# %%
# Visual of selecting best k
plt.figure(figsize=(10, 6))
plt.plot(k_range, cv_scores, marker='o')
plt.xticks(k_range)
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("5-Fold Cross-Validated Accuracy")
plt.title("KNN Accuracy vs. Number of Neighbors (k)")
plt.grid(True)
plt.show()

# %%
# Generate lambda values as the inverse of C
lambdas = 1 / np.logspace(-3, 3, 50)
coefs = []

# Fit the model for each value of C
for C in np.logspace(-3, 3, 50):
    model = LogisticRegression(penalty='l1', solver='liblinear', C=C, random_state=42)
    model.fit(X_train, y_train)
    coefs.append(model.coef_[0])

coefs = np.array(coefs)

# Plotting the coefficient paths against lambda
plt.figure(figsize=(10, 6))
for i, coef_path in enumerate(coefs.T):
    plt.plot(lambdas, coef_path, label=X_train.columns[i], alpha=0.6)

plt.xscale("log")
plt.xlabel("Lambda (Regularization Strength)")
plt.ylabel("Coefficient Value")
plt.title("L1 Logistic Regression Coefficient Paths")
plt.axhline(0, color='black', linestyle='--')
plt.grid()
plt.tight_layout()
plt.show()

# Identify best lambda
print("Best lambda (1/C):", 1 / grid_search.best_params_['C'])
# Out:
# Best lambda (1/C): 0.1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 30
#      27 # Identify best lambda
#      28 print("Best lambda (1/C):", 1 / grid_search.best_params_['C'])
# ---> 30 print(f"Number of features left in the model: {len(selected_feature_names)}")
#
# NameError: name 'selected_feature_names' is not defined

# %%
# Selected features from final model
coefs_final = model.coef_[0]
selected_features = [i for i, c in enumerate(coefs_final) if c != 0]
selected_feature_names = [X_train.columns[i] for i in selected_features]
print(f"Number of features left in the model: {len(selected_feature_names)}")
# Out:
# Number of features left in the model: 113

# %%
# Feature importance for Lasso
lasso_importances = np.abs(lasso_model.coef_[0])  # <-- use coefficients
sorted_idx = np.argsort(lasso_importances)[::-1][:20]  # Top 20

plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_idx)), lasso_importances[sorted_idx][::-1], align='center')
plt.yticks(range(len(sorted_idx)), np.array(feature_names)[sorted_idx][::-1])
plt.xlabel('Feature Importance Score (|Coefficient|)')
plt.title('Top 20 Most Important Features (Lasso Logistic Regression)')
plt.tight_layout()
plt.show()

# %%
# Feature importance for Random Forest
rf_importances = rf_model.feature_importances_
sorted_idx = np.argsort(rf_importances)[::-1][:20]

plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_idx)), rf_importances[sorted_idx][::-1], align='center')
plt.yticks(range(len(sorted_idx)), feature_names[sorted_idx][::-1])
plt.xlabel('Feature Importance Score')
plt.title('Top 20 Most Important Features (Random Forest)')
plt.tight_layout()
plt.show()

# %%
# Analyzing sparsity of dataset

true_counts = data.select_dtypes(include='bool').sum()
true_counts_sorted = true_counts.sort_values(ascending=False)

# Display full output
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

print(true_counts_sorted)
# Out:
# Working Professional or Student_Working Professional    112799
# Gender_Male                                              77464
# Family History of Mental Illness_Yes                     69942
# Have you ever had suicidal thoughts ?_Yes                69562
# Profession_Teacher                                       61536
# Dietary Habits_Moderate                                  49709
# Dietary Habits_Unhealthy                                 46227
# Dietary Habits_Healthy                                   44741
# Sleep Duration_Less than 5 hours                         38784
# Sleep Duration_7-8 hours                                 36969
# Sleep Duration_More than 8 hours                         32726
# Sleep Duration_5-6 hours                                 32142
# Degree_Class 12                                          14731
# Degree_B.Ed                                              11691
# Degree_B.Arch                                             8742
# Degree_B.Com                                              8113
# Profession_Content Writer                                 7814
# City_Kalyan                                               6591
# City_Patna                                                5924
# Degree_B.Pharm                                            5856
# City_Vasai-Virar                                          5765
# Degree_BCA                                                5739
# City_Kolkata                                              5689
# Degree_M.Ed                                               5668
# City_Ahmedabad                                            5613
# City_Meerut                                               5528
# Degree_MCA                                                5234
# City_Ludhiana                                             5226
# City_Pune                                                 5210
# City_Rajkot                                               5207
# City_Visakhapatnam                                        5176
# City_Srinagar                                             5074
# Degree_BBA                                                5030
# Degree_BSc                                                5027
# City_Mumbai                                               4966
# Degree_MSc                                                4879
# City_Indore                                               4872
# City_Agra                                                 4684
# Degree_LLM                                                4647
# City_Surat                                                4636
# City_Varanasi                                             4606
# City_Vadodara                                             4568
# Degree_M.Pharm                                            4537
# City_Hyderabad                                            4496
# Degree_M.Tech                                             4475
# Degree_B.Tech                                             4425
# City_Kanpur                                               4398
# Profession_Architect                                      4370
# Degree_LLB                                                4348
# City_Jaipur                                               4328
# Degree_BHM                                                4305
# City_Thane                                                4289
# City_Lucknow                                              4280
# Profession_Consultant                                     4229
# City_Nagpur                                               4209
# City_Bangalore                                            4123
# City_Chennai                                              4044
# Profession_HR Manager                                     4022
# Profession_Pharmacist                                     3893
# Degree_MBA                                                3818
# Degree_BA                                                 3750
# Degree_ME                                                 3632
# City_Ghaziabad                                            3620
# City_Delhi                                                3593
# City_Bhopal                                               3475
# Degree_MD                                                 3383
# Degree_MHM                                                3286
# City_Faridabad                                            3268
# Profession_Doctor                                         3255
# Profession_Business Analyst                               3161
# City_Nashik                                               3144
# Degree_BE                                                 3104
# Degree_PhD                                                3103
# Degree_M.Com                                              3094
# Degree_MBBS                                               3082
# Profession_Entrepreneur                                   2968
# Profession_Chemist                                        2967
# Degree_MA                                                 2887
# Profession_Chef                                           2862
# Profession_Educational Consultant                         2852
# Profession_Data Scientist                                 2390
# Profession_Researcher                                     2328
# Profession_Lawyer                                         2212
# Profession_Customer Support                               2055
# Profession_Marketing Manager                              1976
# Profession_Pilot                                          1913
# Profession_Travel Consultant                              1860
# Profession_Plumber                                        1748
# Profession_Sales Executive                                1739
# Profession_Manager                                        1737
# Profession_Judge                                          1712
# Profession_Electrician                                    1582
# Profession_Financial Analyst                              1574
# Profession_Software Engineer                              1510
# Profession_Civil Engineer                                 1470
# Profession_UX/UI Designer                                 1452
# Profession_Digital Marketer                               1372
# Profession_Accountant                                     1339
# Profession_Finanancial Analyst                            1329
# Profession_Mechanical Engineer                            1177
# Profession_Graphic Designer                               1163
# Profession_Research Analyst                                690
# Profession_Investment Banker                               393
# Sleep Duration_3-4 hours                                    12
# Sleep Duration_6-7 hours                                     8
# Sleep Duration_4-5 hours                                     7
# Profession_Student                                           7
# City_Mihir                                                   7
# Sleep Duration_4-6 hours                                     5
# Sleep Duration_2-3 hours                                     5
# Degree_M.Arch                                                5
# City_Nandini                                                 4
# Sleep Duration_6-8 hours                                     4
# Sleep Duration_1-6 hours                                     4
# Sleep Duration_No                                            4
# Degree_UX/UI Designer                                        4
# City_Vidya                                                   3
# City_Pratyush                                                3
# Degree_Kalyan                                                3
# Degree_B.Sc                                                  3
# City_Harsha                                                  3
# Degree_M                                                     3
# Profession_Yogesh                                            3
# Profession_Unemployed                                        3
# City_Mahi                                                    3
# City_City                                                    3
# City_Bhavna                                                  3
# Profession_Profession                                        3
# Profession_BCA                                               3
# City_Saanvi                                                  3
# City_Molkata                                                 2
# Degree_P.Com                                                 2
# Dietary Habits_Yes                                           2
# Degree_B                                                     2
# Sleep Duration_10-11 hours                                   2
# Sleep Duration_45                                            2
# Degree_BEd                                                   2
# City_MCA                                                     2
# Degree_Jhanvi                                                2
# City_Keshav                                                  2
# Degree_LLBA                                                  2
# Sleep Duration_8-9 hours                                     2
# Sleep Duration_9-11 hours                                    2
# Sleep Duration_Unhealthy                                     2
# Sleep Duration_Sleep_Duration                                2
# Degree_LL B.Ed                                               2
# City_M.Com                                                   2
# Degree_BPharm                                                2
# Degree_Degree                                                2
# Degree_Nalini                                                2
# Profession_MBA                                               2
# Dietary Habits_More Healthy                                  2
# Degree_BArch                                                 2
# Profession_PhD                                               2
# Degree_MEd                                                   2
# Dietary Habits_No                                            2
# Degree_Bhopal                                                2
# City_Nalini                                                  2
# City_Ayush                                                   2
# Profession_LLM                                               2
# Degree_L.Ed                                                  2
# City_Atharv                                                  2
# Degree_Bhavesh                                               1
# Degree_Badhya                                                1
# Degree_HR Manager                                            1
# City_Ithal                                                   1
# Degree_K.Ed                                                  1
# City_Jhanvi                                                  1
# City_Ivaan                                                   1
# Degree_Brit                                                  1
# Degree_Brithika                                              1
# Degree_H_Pharm                                               1
# Degree_Esha                                                  1
# Degree_B.Student                                             1
# Degree_Business Analyst                                      1
# City_Kagan                                                   1
# Degree_BPA                                                   1
# Degree_Class 11                                              1
# City_Itheg                                                   1
# City_Ishkarsh                                                1
# Degree_Data Scientist                                        1
# Degree_Doctor                                                1
# Degree_HCA                                                   1
# Degree_E.Tech                                                1
# City_Kashish                                                 1
# City_Kashk                                                   1
# Degree_Entrepreneur                                          1
# Degree_BH                                                    1
# Degree_CGPA                                                  1
# Degree_BB                                                    1
# Profession_BBA                                               1
# Degree_LCA                                                   1
# Degree_RCA                                                   1
# Degree_Marsh                                                 1
# Degree_Mihir                                                 1
# Degree_Mthanya                                               1
# Degree_N.Pharm                                               1
# Degree_Navya                                                 1
# Degree_P.Pharm                                               1
# City_Anvi                                                    1
# Degree_Pihu                                                  1
# Degree_Plumber                                               1
# Degree_Ritik                                                 1
# Degree_LHM                                                   1
# Degree_S.Arch                                                1
# Degree_S.Pharm                                               1
# Degree_S.Tech                                                1
# Degree_Unite                                                 1
# Degree_Veda                                                  1
# Degree_Vivaan                                                1
# Degree_Vrinda                                                1
# Degree_Working Professional                                  1
# City_Aishwarya                                               1
# Degree_Mahika                                                1
# Degree_M_Tech                                                1
# Degree_MTech                                                 1
# City_Armaan                                                  1
# Degree_LL.Com                                                1
# City_Ishanabad                                               1
# Degree_LLCom                                                 1
# Degree_LLEd                                                  1
# Degree_LLS                                                   1
# Degree_LLTech                                                1
# City_Khushi                                                  1
# Degree_Lata                                                  1
# Degree_M. Business Analyst                                   1
# City_Harsh                                                   1
# City_Gurgaon                                                 1
# City_Gaurav                                                  1
# Degree_M.S                                                   1
# City_Galesabad                                               1
# City_Dhruv                                                   1
# City_Chhavi                                                  1
# City_Ayansh                                                  1
# Degree_MPA                                                   1
# Degree_MPharm                                                1
# City_Khaziabad                                               1
# Degree_20                                                    1
# Degree_B.B.Arch                                              1
# Sleep Duration_40-45 hours                                   1
# City_Parth                                                   1
# City_No                                                      1
# Profession_Medical Doctor                                    1
# Profession_Moderate                                          1
# Profession_Nagpur                                            1
# Profession_Patna                                             1
# City_Nalyan                                                  1
# City_Morena                                                  1
# Profession_Pranav                                            1
# City_Moreadhyay                                              1
# City_Mira                                                    1
# City_Malyansh                                                1
# City_MSc                                                     1
# Profession_Unveil                                            1
# Profession_Visakhapatnam                                     1
# Profession_Working Professional                              1
# Profession_Yuvraj                                            1
# Sleep Duration_1-3 hours                                     1
# Sleep Duration_10-6 hours                                    1
# City_Aaradhya                                                1
# Sleep Duration_3-6 hours                                     1
# Profession_MBBS                                              1
# Profession_M.Ed                                              1
# City_Plata                                                   1
# Profession_Dev                                               1
# Profession_BE                                                1
# Profession_B.Ed                                              1
# Profession_B.Com                                             1
# Profession_Analyst                                           1
# Profession_City Manager                                      1
# City_Aditya                                                  1
# City_Vidhi                                                   1
# City_Vaishnavi                                               1
# City_Vaanya                                                  1
# City_Unirar                                                  1
# City_Pooja                                                   1
# City_Tushar                                                  1
# City_Tolkata                                                 1
# City_Shrey                                                   1
# Profession_Family Consultant                                 1
# Profession_FamilyVirar                                       1
# City_Reyansh                                                 1
# City_Researcher                                              1
# City_Rashi                                                   1
# City_Raghavendra                                             1
# City_ME                                                      1
# Sleep Duration_45-48 hours                                   1
# City_Kibara                                                  1
# Sleep Duration_49 hours                                      1
# Dietary Habits_Male                                          1
# Dietary Habits_Mihir                                         1
# City_Krishna                                                 1
# Dietary Habits_No Healthy                                    1
# Dietary Habits_Pratham                                       1
# City_Krinda                                                  1
# Dietary Habits_Vegas                                         1
# Degree_24                                                    1
# Degree_29                                                    1
# Degree_5.56                                                  1
# Degree_5.61                                                  1
# Degree_5.88                                                  1
# Degree_7.06                                                  1
# Degree_8.56                                                  1
# Degree_ACA                                                   1
# Degree_Aarav                                                 1
# Degree_Advait                                                1
# Degree_B B.Com                                               1
# Degree_B BA                                                  1
# Degree_B.03                                                  1
# Degree_B.3.79                                                1
# Dietary Habits_M.Tech                                        1
# Dietary Habits_Less than Healthy                             1
# Dietary Habits_Less Healthy                                  1
# Sleep Duration_Pune                                          1
# Sleep Duration_55-66 hours                                   1
# City_M.Tech                                                  1
# Sleep Duration_8 hours                                       1
# Sleep Duration_9-5                                           1
# Sleep Duration_9-5 hours                                     1
# Sleep Duration_9-6 hours                                     1
# Sleep Duration_Indore                                        1
# Sleep Duration_Moderate                                      1
# City_Less than 5 Kalyan                                      1
# Sleep Duration_Work_Study_Hours                              1
# Dietary Habits_Indoor                                        1
# Sleep Duration_than 5 hours                                  1
# Dietary Habits_2                                             1
# Dietary Habits_3                                             1
# Dietary Habits_BSc                                           1
# Dietary Habits_Class 12                                      1
# Dietary Habits_Electrician                                   1
# Dietary Habits_Gender                                        1
# City_Less Delhi                                              1
# Dietary Habits_Hormonal                                      1
# Sleep Duration_35-36 hours                                   1
# dtype: int64

# %% [markdown]
# # Prepare submission file

# %%
# Count the number of missing values
missing_values_count = submission.isnull().sum()
total_missing_values = missing_values_count.sum()

print(f"Total missing values in the dataset: {total_missing_values}")

# Match the columns of submission to the columns of data
submission = submission[X.columns]
# Out:
# Total missing values in the dataset: 0

# %%
submission_y = xgb_model.predict(submission)
